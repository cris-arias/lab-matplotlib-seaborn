# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Seaborn

sns.lineplot(x=x, y=y)

# %%
sns.lineplot(x=x, y=z)

# %%
# Matplotlib

# fig, ax = plt.subplots(figsize = (rows, columns))
# We call the axis with ax.plot(x, y, label='', color='', etc.) Here we can add several attributes

'''''''''
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
ax1.plot()
ax1.legend("Whatever the legend is",loc="upper left")
ax1.set_xscale()
ax1.set_yscale()
ax1.set_title()
ax1.set_xlabel()
ax1.set_ylabel()
ax1.tick_params(axis='y', rotation=45)
ax1.grid(True)
ax2.plot()
ax2.legend("x",loc="upper left")
ax2.set_xscale()
ax2.set_yscale()
ax2.set_title()
ax2.set_xlabel()
ax2.set_ylabel()
ax2.tick_params(axis='y', rotation=45, labelsize= 15)
ax2.grid(True)
fig.tight_layout(pad=2)

'''''''''
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,8))
ax1.plot(x, y, color='r', linestyle='--')
ax2.plot(x, z, color='g')

ax1.set(xlabel='x', ylabel='y',
       title='linear')
ax2.set(xlabel='x', ylabel='z',
       title='quadratic')
ax1.grid()
ax2.grid()

# fig.savefig("test.png")
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,8))
ax1.plot(x, y, color='r', linestyle='--')
ax2.plot(x, z, color='g')

ax1.set(xlabel='x', ylabel='y',
       title='linear')
ax2.set(xlabel='x', ylabel='z',
       title='quadratic')
ax1.grid()
ax2.grid()


ax1.set_xlabel('x', fontweight='bold', fontsize=20, color='r')
ax1.set_ylabel('y', fontweight='bold', fontsize=40, color='g')

ax2.set_xlabel('x', fontweight='bold', fontsize=50, color='b')
ax2.set_ylabel('y', fontweight='bold', fontsize=15, color='y')

# fig.savefig("test.png")
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
y=x**2
y=np.exp(x)

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
ax1.plot(x, y, color='r', linestyle='--')
ax2.plot(x, z, color='g')
ax1.set_xscale('linear')
ax2.set_yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
ax1.plot(x, y, color='r', linestyle='--')
ax2.plot(x, z, color='g')
ax1.set_xscale('linear')
ax2.set_yscale('log')


ax1.legend(title="legend", loc="upper left", mode='expand')
ax2.legend("legend",loc="upper right")
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit=pd.read_csv('Fitbit2.csv')
original=fitbit.copy()

# %%
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        367 non-null    object
#  1   Calorie burned              367 non-null    int64
#  2   Steps                       367 non-null    int64
#  3   Distance                    367 non-null    float64
#  4   Floors                      367 non-null    int64
#  5   Minutes Sedentary           367 non-null    float64
#  6   Minutes Lightly Active      367 non-null    int64
#  7   Minutes Fairly Active       367 non-null    int64
#  8   Minutes Very Active         367 non-null    int64
#  9   Activity Calories           367 non-null    int64
#  10  MinutesOfSleep              367 non-null    int64
#  11  MinutesOfBeingAwake         367 non-null    int64
#  12  NumberOfAwakings            367 non-null    int64
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fig, [ax1, ax2] = plt.subplots(1,2, figsize = (12,4))

plt.sca(ax1)
fitbit.groupby('Months_encoded')["Steps"].mean().plot()
plt.xticks(range(12),['Jan','Feb', 'Mar', 'Apr', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)
plt.sca(ax2)
fitbit.groupby("Work_or_Weekend")["Steps"].mean().plot.bar()
plt.xticks(range(2),['work', 'weekend'], rotation=45)


'''''''''
fig, [ax1, ax2] = plt.subplots(1,2, figsize = (12,4))

ax1.plot(month_encoded)
ax1.set_title('months_encoded')
ax1.set_xlabel('steps')
ax1.set_ylabel('months_encoded')


ax2.plot(work_or_weekend)
ax2.set_title('work_or_weekend')
ax1.set_xlabel('steps')
ax1.set_ylabel('work_or_weekend')

'''''''''
# Out:
# "\nfig, [ax1, ax2] = plt.subplots(1,2, figsize = (12,4))\n\nax1.plot(month_encoded)\nax1.set_title('months_encoded')\nax1.set_xlabel('steps')\nax1.set_ylabel('months_encoded')\n\n\nax2.plot(work_or_weekend)\nax2.set_title('work_or_weekend')\nax1.set_xlabel('steps')\nax1.set_ylabel('work_or_weekend')\n\n"

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
#
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
f, ax = plt.subplots(1, 3, figsize=(12, 8))
value = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']
for i in range(3):
    plt.sca(ax[i])
    ax[i].set_title(value[i])
    plt.scatter(fitbit['Steps'], fitbit[value[i]])

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic=pd.read_csv('titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES

# PassengerId      int64
# Survived       float64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64

titanic.select_dtypes(include=('int64','float64'))
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES

# Name            object
# Gender          object
# Ticket          object
# Cabin           object
# Embarked        object

titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
f, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].scatter(titanic['Gender'], titanic['Age'])
ax[1].bar(titanic['Cabin'], titanic['Fare'])
# Out:
# <BarContainer object of 1309 artists>

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.hist(x=titanic['Age'])
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
bins=[10, 20, 50]

for i in bins:
    plt.hist(x=titanic['Age'], bins=i)

# %%
f, ax=plt.subplots(1,3, figsize=(12,6))
ax[0].hist(titanic['Age'], bins=10)
ax[1].hist(titanic['Age'], bins=20)
ax[2].hist(titanic['Age'], bins=50)
# Out:
# (array([ 22.,  19.,  10.,  11.,  10.,  13.,   8.,   8.,  23.,  26.,  20.,
#          75.,  29.,  93., 109.,  43.,  72.,  68., 111.,  53.,  71.,  47.,
#          35.,  24.,  43.,  26.,  29.,  15.,  35.,  31.,  15.,  26.,   7.,
#          14.,  13.,   5.,   9.,   8.,  11.,   9.,   3.,   2.,   0.,   2.,
#           3.,   0.,   1.,   1.,   0.,   1.]),
#  array([ 0.17  ,  1.7666,  3.3632,  4.9598,  6.5564,  8.153 ,  9.7496,
#         11.3462, 12.9428, 14.5394, 16.136 , 17.7326, 19.3292, 20.9258,
#         22.5224, 24.119 , 25.7156, 27.3122, 28.9088, 30.5054, 32.102 ,
#         33.6986, 35.2952, 36.8918, 38.4884, 40.085 , 41.6816, 43.2782,
#         44.8748, 46.4714, 48.068 , 49.6646, 51.2612, 52.8578, 54.4544,
#         56.051 , 57.6476, 59.2442, 60.8408, 62.4374, 64.034 , 65.6306,
#         67.2272, 68.8238, 70.4204, 72.017 , 73.6136, 75.2102, 76.8068,
#         78.4034, 80.    ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The bigger the bins, the smaller the interval and the more precise the representation 
"""
# Out:
# '\nThe bigger the bins, the smaller the interval and the more precise the representation \n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
m_f_count = titanic['Gender'].value_counts()
m_f_count
# Out:
# male      843
# female    466
# Name: Gender, dtype: int64

# %%
# Method 1 - matplotlib
plt.pie(titanic.Gender.value_counts(), labels=('male', 'female'))
# Out:
# ([<matplotlib.patches.Wedge at 0x126ef2160>,
# ...
#  [Text(-0.48083677220945115, 0.9893411941747885, 'male'),
#   Text(0.48083667958064136, -0.9893412391939718, 'female')])

# %%
# Method 2 - seaborn
sns.countplot(x = titanic['Gender'])

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# Even when Pclass data type is an integer, we are interested in the cualitative aspect of it (how many people wen in 1st, 2nd and 3rd class)
# Therefore, we can use the same approach as before
sns.countplot(x = titanic['Pclass'])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# Matplotlib
sns.boxplot(titanic['Age'])

# %%
"""
The boxplot shows nicely the median and outliers (min and max) of the distribution, hence giving a nice overviewof the dataset.

"""
# Out:
# '\nThe boxplot shows nicely the median and outliers (min and max) of the distribution, hence giving a nice overviewof the dataset.\n\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
In this case we see that the median falls in 30 years old.
Most people were between 20 and 30 years old.
There are several outliers though of people over 60 which skew the data distribution.
"""
# Out:
# '\nIn this case we see that the median falls in 30 years old.\nMost people were between 20 and 30 years old.\nThere are several outliers though of people over 60 which skew the data distribution.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# seaborn
sns.distplot(titanic['Age'])

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Age follows approximately a normal distribution

"""
# Out:
# '\nAge follows approximately a normal distribution\n\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 2 - seaborn
sns.regplot(titanic['Age'], titanic['Fare'])

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
sns.heatmap(titanic.corr())

# %%
titanic_corr = titanic.corr()
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(titanic_corr, cmap=cmap)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(titanic['Pclass'], titanic['Age'])

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
age_gend_grid = sns.FacetGrid(titanic, col = 'Gender') #call the empty boxes. P.class have 3 different values
age_gend_grid.map(sns.boxplot,"Age") #ask for a certain type of graph/plot to fill the boxes. Age has many different values
#in col=' ' we prefer to add the one with les different values, in this case, Pclass
# Out:
# /usr/local/Cellar/jupyterlab/2.1.4/libexec/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
